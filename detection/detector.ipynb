# %% [markdown]
# ## Use best-performing algorithm to extract faces from dataset ##

# %%
from detector_utils import *
# Out:
# 2023-09-29 14:44:53.610909: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-29 14:44:53.633718: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-29 14:44:53.789930: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-29 14:44:53.790849: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
root_dir = "/home/daniel/dataset"
dest_dir = "/home/daniel/dataset_preprocess"

label_and_preprocess_frames(root_dir, dest_dir)
# Out:
# Total number of people: 36
# Total number of frames: 76213
#
# Number of situations: 5
# Situation No Glasses: 14692 frames
# Situation With Glasses: 15583 frames
# Situation Night No Glasses: 15386 frames
# Situation Night With Glasses: 16074 frames
# Situation Sunglasses: 14478 frames
#
# Number of categories: 3
# Category Normal: 47393 frames
# Category Drowsy: 24255 frames
# Category Distracted: 4565 frames

# %%
show_random_sample(dest_dir)

# %%
dest_dir_mp = "/home/daniel/dataset_mp"
mediapipe_face_detector(dest_dir, dest_dir_mp)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Processing category: anormal
# Processing category: adistracted
# Processing category: aclosed
# Frame selection and copying completed.

# %%
print_dataset(dest_dir_mp)
# Out:
# Total number of frames: 75591
#
# Category Normal: 47390 frames
# Category Drowsy: 23815 frames
# Category Distracted: 4386 frames

# %%
over_sampling(dest_dir_mp)
under_sampling(dest_dir_mp)

# %%
print_dataset(dest_dir_mp)
# Out:
# Total number of frames: 35980
#
# Category Normal: 12008 frames
# Category Drowsy: 11908 frames
# Category Distracted: 12064 frames

# %%
dest_dir_final = "/home/daniel/final"
split_data(dest_dir_final)
# Out:
# Dataset split completed.

# %%
train_dir = "/home/daniel/final/train"
test_dir = "/home/daniel/final/test"
val_dir = "/home/daniel/final/val"

print("Training Size:")
print_dataset(train_dir)

print("Test Size:")
print_dataset(test_dir)

print("Validation Size:")
print_dataset(val_dir)
# Out:
# Training Size:
# Total number of frames: 25184
#
# Category Normal: 8405 frames
# Category Drowsy: 8335 frames
# Category Distracted: 8444 frames
#
# Test Size:
# Total number of frames: 5396
#
# Category Normal: 1801 frames
# Category Drowsy: 1786 frames
# Category Distracted: 1809 frames
#
# Validation Size:
# Total number of frames: 5400
#
# Category Normal: 1802 frames
# Category Drowsy: 1787 frames
# Category Distracted: 1811 frames
